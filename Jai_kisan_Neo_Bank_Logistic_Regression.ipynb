# %% [markdown]
# <a href="https://colab.research.google.com/github/995903/Mlops_1/blob/main/Jai_kisan_Neo_Bank_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/002/043/original/jai_kisan_logistic_regression.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
df.shape
# Out:
# (396030, 27)

# %%
df.size
# Out:
# 10692810

# %%
df.emp_title.value_counts() # This is categorical data, but this is data we have many categories
# Out:
# Teacher                    4389
# Manager                    4250
# Registered Nurse           1856
# RN                         1846
# Supervisor                 1830
#                            ...
# Postman                       1
# McCarthy & Holthus, LLC       1
# jp flooring                   1
# Histology Technologist        1
# Gracon Services, Inc          1
# Name: emp_title, Length: 173105, dtype: int64

# %%
df.emp_length.value_counts() # This is categorical data, but this is data we have 11 categories
# Out:
# 10+ years    126041
# 2 years       35827
# < 1 year      31725
# 3 years       31665
# 5 years       26495
# 1 year        25882
# 4 years       23952
# 6 years       20841
# 7 years       20819
# 8 years       19168
# 9 years       15314
# Name: emp_length, dtype: int64

# %%
df.emp_length.value_counts() # This is categorical data, but this is data we have 11 categories
# Out:
# 10+ years    126041
# 2 years       35827
# < 1 year      31725
# 3 years       31665
# 5 years       26495
# 1 year        25882
# 4 years       23952
# 6 years       20841
# 7 years       20819
# 8 years       19168
# 9 years       15314
# Name: emp_length, dtype: int64

# %%
df.verification_status.value_counts() # we have 3 categories, we called it as categorical column
# Out:
# Verified           139563
# Source Verified    131385
# Not Verified       125082
# Name: verification_status, dtype: int64

# %%
df.home_ownership.value_counts() # we have 6 categories , we called it as Categorical column
# Out:
# MORTGAGE    198348
# RENT        159790
# OWN          37746
# OTHER          112
# NONE            31
# ANY              3
# Name: home_ownership, dtype: int64

# %%
# Continuous Variables - Distribution Plots
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], bins=30, kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
# Categorical Variables - Count Plots
for column in df.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=column, data=df, order=df[column].value_counts().index)
    plt.title(f'Count Plot of {column}')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d0df929f0eac> in <cell line: 2>()
#       2 for column in df.select_dtypes(include=['object']).columns:
#       3     plt.figure(figsize=(10, 6))
# ----> 4     sns.countplot(x=column, data=df, order=df[column].value_counts().index)
#       5     plt.title(f'Count Plot of {column}')
#       6     plt.xticks(rotation=45)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2953         ax = plt.gca()
#    2954
# -> 2955     plotter.plot(ax, kwargs)
#    2956     return ax
#    2957
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1585         """Make the plot."""
#    1586         self.draw_bars(ax, bar_kws)
# ...

# %%
# Out:
# 173105

# %%
# Relationship between continuous variables and the target variable
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='loan_status', y=column, data=df)
    plt.title(f'Boxplot of {column} by Loan Status')
    plt.show()

# %%
# Relationship between categorical variables and the target variable
for column in df.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=column, hue='loan_status', data=df, order=df[column].value_counts().index)
    plt.title(f'Count Plot of {column} by Loan Status')
    plt.xticks(rotation=45)
    plt.show()
